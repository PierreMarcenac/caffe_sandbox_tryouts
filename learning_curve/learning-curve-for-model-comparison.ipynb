# %% [markdown]
# # Models comparison on MNIST

# %%
# %pylab inline
import mnist_train_test
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nets = [("net0", "caffe_net0_20160325_171154.log"),
        ("net1", "caffe_net1_20160325_171154.log"),
        ("net2", "caffe_net2_20160325_171154.log")]
for net_prefix, log_name in nets:
    log_name = "logs/" + log_name
    fig_name = net_prefix + ".png"
    mnist_train_test.print_learning_curve(net_prefix, log_name, fig_name, inline=True)
